# %%
from manim import *

config.media_width = "75%"
config.verbosity = "WARNING"

# %%
ManimColor("#000000", alpha=1)
# Out:
# ManimColor('#000000')

# %%
# %%manim -qm ThreeDLightSourcePosition
#
#
# class ThreeDLightSourcePosition(ThreeDScene):
#     def construct(self):
#         axes = ThreeDAxes()
#         sphere = Surface(
#             lambda u, v: np.array([
#                 1.5 * np.cos(u) * np.cos(v),
#                 1.5 * np.cos(u) * np.sin(v),
#                 1.5 * np.sin(u)
#             ]), v_range=[0, TAU], u_range=[-PI / 2, PI / 2],
#             checkerboard_colors=[ManimColor("#fff", alpha=0), ManimColor("#000", alpha=1)], resolution=(15, 32)
#         )
#         self.renderer.camera.light_source.move_to(3*IN) # changes the source of the light
#         self.set_camera_orientation(phi=75 * DEGREES, theta=30 * DEGREES)
#         self.add(axes, sphere)
# Out:
# Manim Community v0.19.0
# [10/18/25 22:46:55] INFO                                                                   ]8;id=822072;file:///Users/hun/LabMeeting/.venv/lib/python3.12/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=963886;file:///Users/hun/LabMeeting/.venv/lib/python3.12/site-packages/manim/scene/scene_file_writer.py#886\886]8;;\
#                              File ready at
#                              '/Users/hun/LabMeeting/media/images/LabMeeting/ThreeDLightSou
#                              rcePosition_ManimCE_v0.19.0.png'
#                     INFO     Rendered ThreeDLightSourcePosition                                        ]8;id=30591;file:///Users/hun/LabMeeting/.venv/lib/python3.12/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=382384;file:///Users/hun/LabMeeting/.venv/lib/python3.12/site-packages/manim/scene/scene.py#255\255]8;;\
#                              Played 0 animations
